# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('player_stats_baseball.csv')

# %%
df
# Out:
#      last_name  first_name  player_id  year  player_age  b_ab  b_total_hits  \
# 0     Blackmon     Charlie     453568  2023          36    44            15
# 1       Solano     Donovan     456781  2023          35    38            13
# 2    McCutchen      Andrew     457705  2023          36    34            11
# 3       Turner      Justin     457759  2023          38    47            12
# 4       Andrus       Elvis     462101  2023          34    48             7
# ..         ...         ...        ...   ...         ...   ...           ...
# 595      Edman       Tommy     669242  2021          26   641           168
# 596      Solak        Nick     669256  2021          26   458           111
# 597       Hays      Austin     669720  2021          25   488           125
# 598      Lopez       Nicky     670032  2021          26   497           149
# 599    Alvarez      Yordan     670541  2021          24   537           149
#
#      b_home_run  b_bb_percent  batting_avg  on_base_percent  on_base_plus_slg  \
# 0             1           8.0        0.341            0.420             0.897
# 1             0           4.9        0.342            0.390             0.811
# 2             1          21.3        0.324            0.468             0.968
# 3             0          13.8        0.255            0.379             0.698
# 4             0           2.0        0.146            0.176             0.343
# ..          ...           ...          ...              ...               ...
# 595          11           5.5        0.262            0.307             0.694
# 596          11           6.7        0.242            0.313             0.676
# 597          22           5.3        0.256            0.306             0.767
# 598           2           8.7        0.300            0.358             0.736
# 599          33           8.4        0.277            0.346             0.877
#
#      b_rbi  b_game  r_run  exit_velocity_avg  launch_angle_avg  \
# 0        4      12      6               83.3              17.4
# 1        3      11      4               90.9              14.9
# 2        4      12      5               89.4              20.8
# 3        4      13      7               89.6              11.9
# 4        4      13      3               88.6               4.1
# ..     ...     ...    ...                ...               ...
# 595     56     159     91               87.5               9.5
# 596     49     127     57               86.9               7.0
# 597     71     131     73               88.8              12.5
# 598     43     151     78               86.8               2.8
# 599    104     144     92               93.2              14.1
#
#      sweet_spot_percent  barrel_batted_rate  Unnamed: 19
# 0                  45.0                 5.0          NaN
# 1                  46.7                 3.3          NaN
# 2                  41.4                10.3          NaN
# 3                  31.7                 0.0          NaN
# 4                  30.0                 0.0          NaN
# ..                  ...                 ...          ...
# 595                31.5                 4.2          NaN
# 596                29.3                 6.5          NaN
# 597                32.2                 9.1          NaN
# 598                27.6                 0.7          NaN
# 599                37.2                15.9          NaN
#
# [600 rows x 20 columns]

# %%
sns.histplot(df.r_run, kde=True)
plt.xlabel('runs')
plt.title('Runs per player')
# Out:
# Text(0.5, 1.0, 'Runs per player')

# %%
sns.scatterplot(x = df.exit_velocity_avg, y = df.launch_angle_avg)
plt.xlabel('exit velocity')
plt.ylabel('launch angle')
plt.title('Distribution of hits comparing average \n launch angle and exit velocity of players')
# Out:
# Text(0.5, 1.0, 'Distribution of hits comparing average \n launch angle and exit velocity of players')

# %%
df['above_batavg'] = np.select([df.batting_avg > 0.25, df.batting_avg <= 0.25] , [0,1])

# %%
df
# Out:
#      last_name  first_name  player_id  year  player_age  b_ab  b_total_hits  \
# 0     Blackmon     Charlie     453568  2023          36    44            15
# 1       Solano     Donovan     456781  2023          35    38            13
# 2    McCutchen      Andrew     457705  2023          36    34            11
# 3       Turner      Justin     457759  2023          38    47            12
# 4       Andrus       Elvis     462101  2023          34    48             7
# ..         ...         ...        ...   ...         ...   ...           ...
# 595      Edman       Tommy     669242  2021          26   641           168
# 596      Solak        Nick     669256  2021          26   458           111
# 597       Hays      Austin     669720  2021          25   488           125
# 598      Lopez       Nicky     670032  2021          26   497           149
# 599    Alvarez      Yordan     670541  2021          24   537           149
#
#      b_home_run  b_bb_percent  batting_avg  ...  on_base_plus_slg  b_rbi  \
# 0             1           8.0        0.341  ...             0.897      4
# 1             0           4.9        0.342  ...             0.811      3
# 2             1          21.3        0.324  ...             0.968      4
# 3             0          13.8        0.255  ...             0.698      4
# 4             0           2.0        0.146  ...             0.343      4
# ..          ...           ...          ...  ...               ...    ...
# 595          11           5.5        0.262  ...             0.694     56
# 596          11           6.7        0.242  ...             0.676     49
# 597          22           5.3        0.256  ...             0.767     71
# 598           2           8.7        0.300  ...             0.736     43
# 599          33           8.4        0.277  ...             0.877    104
#
#      b_game  r_run  exit_velocity_avg  launch_angle_avg  sweet_spot_percent  \
# 0        12      6               83.3              17.4                45.0
# 1        11      4               90.9              14.9                46.7
# 2        12      5               89.4              20.8                41.4
# 3        13      7               89.6              11.9                31.7
# 4        13      3               88.6               4.1                30.0
# ..      ...    ...                ...               ...                 ...
# 595     159     91               87.5               9.5                31.5
# 596     127     57               86.9               7.0                29.3
# 597     131     73               88.8              12.5                32.2
# 598     151     78               86.8               2.8                27.6
# 599     144     92               93.2              14.1                37.2
#
#      barrel_batted_rate  Unnamed: 19  above_batavg
# 0                   5.0          NaN             0
# 1                   3.3          NaN             0
# 2                  10.3          NaN             0
# 3                   0.0          NaN             0
# 4                   0.0          NaN             1
# ..                  ...          ...           ...
# 595                 4.2          NaN             0
# 596                 6.5          NaN             1
# 597                 9.1          NaN             0
# 598                 0.7          NaN             0
# 599                15.9          NaN             0
#
# [600 rows x 21 columns]

# %%
sns.scatterplot(x = df.exit_velocity_avg, y = df.launch_angle_avg, hue=df.above_batavg)
plt.xlabel('exit velocity')
plt.ylabel('launch angle')
plt.title('Distribution of hits comparing average \n launch angle and exit velocity of players')
# Out:
# Text(0.5, 1.0, 'Distribution of hits comparing average \n launch angle and exit velocity of players')

# %%
good_players = df[df.batting_avg >0.25]
bad_players = df[df.batting_avg <= 0.25]
bad_players
# Out:
#         last_name  first_name  player_id  year  player_age  b_ab  \
# 4          Andrus       Elvis     462101  2023          34    48
# 5         Santana      Carlos     467793  2023          37    48
# 6         Escobar     Eduardo     500871  2023          34    39
# 9          Segura        Jean     516416  2023          33    44
# 15        Stanton   Giancarlo     519317  2023          33    44
# ..            ...         ...        ...   ...         ...   ...
# 578          Happ         Ian     664023  2021          26   465
# 580          Lowe     Brandon     664040  2021          26   535
# 587  Chisholm Jr.        Jazz     665862  2021          23   464
# 590        Garcia      Adolis     666969  2021          28   581
# 596         Solak        Nick     669256  2021          26   458
#
#      b_total_hits  b_home_run  b_bb_percent  batting_avg  ...  \
# 4               7           0           2.0        0.146  ...
# 5              12           2          11.1        0.250  ...
# 6               4           1           4.7        0.103  ...
# 9               8           0           6.4        0.182  ...
# 15             11           3           4.3        0.250  ...
# ..            ...         ...           ...          ...  ...
# 578           105          25          11.6        0.226  ...
# 580           132          39          11.1        0.247  ...
# 587           115          18           6.7        0.248  ...
# 590           141          31           5.1        0.243  ...
# 596           111          11           6.7        0.242  ...
#
#      on_base_plus_slg  b_rbi  b_game  r_run  exit_velocity_avg  \
# 4               0.343      4      13      3               88.6
# 5               0.813      6      13      5               89.4
# 6               0.345      4      12      3               84.2
# 9               0.416      0      12      2               89.5
# 15              0.783      8      11      6               95.8
# ..                ...    ...     ...    ...                ...
# 578             0.756     66     148     63               89.5
# 580             0.863     99     149     97               89.3
# 587             0.726     53     124     70               90.2
# 590             0.741     90     149     77               91.0
# 596             0.676     49     127     57               86.9
#
#      launch_angle_avg  sweet_spot_percent  barrel_batted_rate  Unnamed: 19  \
# 4                 4.1                30.0                 0.0          NaN
# 5                16.4                44.4                11.1          NaN
# 6                15.7                23.3                 3.3          NaN
# 9                -3.9                25.0                 3.1          NaN
# 15                7.7                28.6                20.0          NaN
# ..                ...                 ...                 ...          ...
# 578               9.9                30.8                10.9          NaN
# 580              16.9                37.2                14.0          NaN
# 587               9.0                29.0                 9.0          NaN
# 590              14.7                29.4                11.5          NaN
# 596               7.0                29.3                 6.5          NaN
#
#      above_batavg
# 4               1
# 5               1
# 6               1
# 9               1
# 15              1
# ..            ...
# 578             1
# 580             1
# 587             1
# 590             1
# 596             1
#
# [236 rows x 21 columns]

# %%
from scipy.stats import ttest_ind
ttest_ind(good_players['launch_angle_avg'], bad_players['launch_angle_avg'])
# Out:
# Ttest_indResult(statistic=-3.854485034189781, pvalue=0.0001285274634018919)

# %%
sns.histplot(df['batting_avg'])
# Out:
# <AxesSubplot:xlabel='batting_avg', ylabel='Count'>

# %%
df = df[df.r_run > 0]
df['runs_per_ab'] = df.r_run / df.b_ab
# Out:
# C:\Users\arist\AppData\Local\Temp\ipykernel_172984\26121197.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs_per_ab'] = df.r_run / df.b_ab

# %%
sns.histplot(df['runs_per_ab'])
# Out:
# <AxesSubplot:xlabel='runs_per_ab', ylabel='Count'>

# %%
sns.regplot(good_players['launch_angle_avg'], good_players['exit_velocity_avg'], color = 'red')
sns.regplot(bad_players['launch_angle_avg'], bad_players['exit_velocity_avg'], color ='blue')
# s
plt.xlabel('exit velocity')
plt.ylabel('launch angle')
plt.title('Distribution of hits comparing average \n launch angle and exit velocity of players')
plt.suptitle('Red: Batting avg > 0.250', y=1.05)
# Out:
# C:\Users\arist\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\arist\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.05, 'Red: Batting avg > 0.250')

# %%
# sns.scatterplot(df['launch_angle_avg'], df['exit_velocity_avg'], hue = 'above_batavg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4160, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4159 try:
# -> 4160     mcolors.to_rgba_array(kwcolor)
#    4161 except ValueError as err:
#
# File ~\anaconda3\lib\site-packages\matplotlib\colors.py:359, in to_rgba_array(c, alpha)
#     358 if isinstance(c, str):
# --> 359     raise ValueError("Using a string of single character colors as "
#     360                      "a color sequence is not supported. The colors can "
#     361                      "be passed as an explicit list instead.")
#     363 if len(c) == 0:
#
# ValueError: Using a string of single character colors as a color sequence is not supported. The colors can be passed as an explicit list instead.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 sns.scatterplot(df['launch_angle_avg'], df['exit_velocity_avg'], color = 'above_batavg')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:827, in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     823     return ax
#     825 p._attach(ax)
# --> 827 p.plot(ax, kwargs)
#     829 return ax
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:608, in _ScatterPlotter.plot(self, ax, kws)
#     603 scout_size = max(
#     604     np.atleast_1d(kws.get("s", [])).shape[0],
#     605     np.atleast_1d(kws.get("c", [])).shape[0],
#     606 )
#     607 scout_x = scout_y = np.full(scout_size, np.nan)
# --> 608 scout = ax.scatter(scout_x, scout_y, **kws)
#     609 s = kws.pop("s", scout.get_sizes())
#     610 c = kws.pop("c", scout.get_facecolors())
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4387, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4384 if edgecolors is None:
#    4385     orig_edgecolor = kwargs.get('edgecolor', None)
#    4386 c, colors, edgecolors = \
# -> 4387     self._parse_scatter_color_args(
#    4388         c, edgecolors, kwargs, x.size,
#    4389         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4391 if plotnonfinite and colors is None:
#    4392     c = np.ma.masked_invalid(c)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4162, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4160     mcolors.to_rgba_array(kwcolor)
#    4161 except ValueError as err:
# -> 4162     raise ValueError(
#    4163         "'color' kwarg must be a color or sequence of color "
#    4164         "specs.  For a sequence of values to be color-mapped, use "
#    4165         "the 'c' argument instead.") from err
#    4166 if edgecolors is None:
#    4167     edgecolors = kwcolor
#
# ValueError: 'color' kwarg must be a color or sequence of color specs.  For a sequence of values to be color-mapped, use the 'c' argument instead.

# %%
sns.histplot(bad_players['launch_angle_avg'])
# Out:
# <AxesSubplot:xlabel='launch_angle_avg', ylabel='Count'>

# %%
sns.histplot(good_players['player_age'], color='red', kde=True)
sns.histplot(bad_players['player_age'], color='blue', kde=True)
# Out:
# <AxesSubplot:xlabel='player_age', ylabel='Count'>

# %%
sns.regplot(x=df.player_age, y=df.batting_avg)
# Out:
# <AxesSubplot:xlabel='player_age', ylabel='batting_avg'>

# %%
sns.regplot(x=df.player_age, y=df.runs_per_ab)
# Out:
# <AxesSubplot:xlabel='player_age', ylabel='runs_per_ab'>

# %%
sns.regplot(x=df.b_ab, y=df.batting_avg)
# Out:
# <AxesSubplot:xlabel='b_ab', ylabel='batting_avg'>

# %%
sns.scatterplot(x=df.player_age, y=df.b_ab)
# Out:
# <AxesSubplot:xlabel='player_age', ylabel='b_ab'>

# %%
sns.scatterplot(x=good_players.player_age, y=good_players.b_ab, color='red')
sns.scatterplot(x=bad_players.player_age, y=bad_players.b_ab, color='blue')
# Out:
# <AxesSubplot:xlabel='player_age', ylabel='b_ab'>

# %%
sns.scatterplot(x=good_players.player_age, y=good_players.batting_avg, color='red')
sns.scatterplot(x=bad_players.player_age, y=bad_players.batting_avg, color='blue')
# Out:
# <AxesSubplot:xlabel='player_age', ylabel='batting_avg'>

# %%
sns.regplot(x=df.batting_avg, y=df.on_base_percent)
# Out:
# <AxesSubplot:xlabel='batting_avg', ylabel='on_base_percent'>

# %%
sns.regplot(x=df.launch_angle_avg, y=df.on_base_percent, color = 'blue')
# Out:
# <AxesSubplot:xlabel='launch_angle_avg', ylabel='on_base_percent'>

# %%
sns.regplot(x=df.exit_velocity_avg, y=df.on_base_percent, color = 'blue')
# Out:
# <AxesSubplot:xlabel='exit_velocity_avg', ylabel='on_base_percent'>

# %%
sns.scatterplot(x=df.player_age, y=df.b_game, color = 'blue')
# Out:
# <AxesSubplot:xlabel='player_age', ylabel='b_game'>
